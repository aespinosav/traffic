# %%
from ta_solver import *from triangulation import *

# %%
g = make_pruned_triangulation(10, 0)rand_shrink_a(g, 0.2, 0.1)plot_net(g)

# %%
g.number_of_edges()
# Out:
# 42

# %%
D = np.arange(0,5, 0.2)

# %%
# %time sols = ta_solve_network(g, D, "UE")
# Out:
# CPU times: user 1.55 s, sys: 0.01 s, total: 1.56 sWall time: 1.54 s

# %%
plot_swithces(g, D, sols)#plt.savefig("test_plot.pdf")

# %%
g.number_of_edges()
# Out:
# 156
